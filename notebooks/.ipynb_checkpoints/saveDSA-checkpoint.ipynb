# %%
import os
import cv2
import numpy as np
from modules.ftu import Tubule
from modules.slide import Slide
from modules.dsa import DSAFolder, DSAItem, DSA

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            # print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1]) 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)<len(cnts) and cnts[f+1][1][3]==-1: #No Children
                        pass
                    else: # Get Children
                        z = f+1
                        holes = []
                        while True:
                            hole = []
                            try:
                                cntChild = cnts[z][0]
                                hieChild = cnts[z][1]
                            except:
                                break
                            if hieChild[3]==-1:
                                break
                            for i in cntChild:
                                for j in i:
                                    x = int(j[0]) 
                                    y = int(j[1]) 
                                    hole.append([x, y, 0])
                            holes.append(hole)
                            z+=1
                        elem["holes"] = holes
                    elems.append(elem)

    anno = {
        "name": 'tbm_ai', 
        "description": 'tbm_ai',  
        "elements": None                        
    }
    anno["elements"] = elems
    annos.append(anno)

    return annos



def getContours(mask):

    def smoothBinary(mask2d):
        kn = 2
        iterat = 2
        kernel = np.ones((kn, kn), np.uint8) 
        for _ in range(iterat):
            mask2d = cv2.erode(mask2d, kernel, iterations=1) 
            mask2d = cv2.dilate(mask2d, kernel, iterations=1) 
        return mask2d
    
    mask2 = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    
    maskSmooth = smoothBinary(mask2)

    thresholdArea = 0.0001

    contours, hierarchy = cv2.findContours(maskSmooth, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    print(f"found {len(contours)} contours")

    c_max = max(contours, key = cv2.contourArea)
    area_min = cv2.contourArea(c_max) * thresholdArea
    
    print(len(contours))
    
    cntheis = sorted(zip(contours, hierarchy[0]), key=lambda b: cv2.contourArea(b[0]) , reverse=True)
    
    mxmx = int(1.0 * len(contours))
    
    contours_filtered = []
    
    for qq in range(mxmx):
        if qq%50==0:
            print(f"processing {qq}/{mxmx}")
        contour = cntheis[qq][0]
        hie = cntheis[qq][1]
        contours_filtered.append((contour,hie))

    return contours_filtered

xx = 95663
yy = 41940

mask = np.zeros((yy, xx, 3), dtype='uint8')

mydir = "/home/manojkumargalla/ResUNet/data/pred_512"

files = os.listdir(mydir)

for file in files:
    lst = file.split('[')[-1].split(']')[0].replace("=", "").replace("x", "").replace("w", "").replace("y", "").replace("h", "").split(",")
    # print(lst)
    x, y, w, h = [int(k) for k in lst]
    mask[y:y+h, x:x+w, :] = cv2.imread( f"{mydir}/{file}",3)

contours = getContours(mask)
contoursColors = [{'cnt': contours, 'color': '255, 20, 20'}]

dsafid = {
    '32-2_PAS_1of2':'6691a0ba0519743b266f59c8',
}

slides2 = [
    '32-2_PAS_1of2'
]

annoooos = {}

for name in slides2:
    config = {
        'fid': dsafid[name],
        'username': 'manojkumargalla',
        'password': '3435isbcmon@G',
        'apiUrl': 'https://athena.rc.ufl.edu/api/v1',
        'layerName': 'tbm_geojson',
        'svsBase': "/blue/pinaki.sarder/nlucarelli/kpmp_new/"
    }

    annos = generateAnno(contoursColors)

    annoooos[name] = annos

    dsa = DSA(config)

    fid = dsafid[name]

    annos = annoooos[name]
    dsa.postAnno(fid, annos)

# %%
def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0]) + contoursColors[q]['x'] 
                        y = int(j[1]) + contoursColors[q]['y'] 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)0:
                slide = Slide(config, svsname)

                slide.extractForeground()

                slide.createBinary(anno)

                patches = slide.extractPairs(config['patchSize'])

                print(len(patches))

                contoursColors = []
                for key in patches:
                    try:
                        patch = patches[key]
                        contours = segmentTBMPair(patch)
                        x, y = key.split('_')
                        contoursColors.append({'x': int(x), 'y': int(y) , 'cnt': contours, 'color': '255, 20, 20'})
                        cv2.imwrite(f"{outdir}/{key}.png", patch)
                    except:
                        pass
                annos = generateAnno(contoursColors)
                dsa.postAnno(fid, annos)
            else:
                logging.warning(f"No annotation found in {fid} __ {svsname}")
        except:
            logging.warning(f"Exeption in {fid} __ {svsname}")

# %%
import cv2
import numpy as np
from modules.ftu import Tubule
import os
from modules.slide import Slide
from modules.dsa import DSAFolder, DSAItem, DSA

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1]) 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

            #     if len(points)>1:
            #         if (f+1) area_min:
            # if area > amin:
            #     msk_ = mask*0
            #     interThickness = 2
            #     cv2.drawContours(msk_, [contour], -1, [255,255,255], interThickness)
            #     if np.sum(msk_*mask)>0:
            #         contours_filtered.append((contour,hie))

    return contours_filtered

xx = 95663
yy = 41940


mask = np.zeros((yy, xx, 3), dtype='uint8')

mydir = "/home/manojkumargalla/ResUNet/data/pred_512_1/32-2_PAS_1of2"

files = os.listdir(mydir)

for file in files:
    # lst = file.split('[')[-1].split(']')[0].replace("=", "").replace("x", "").replace("w", "").replace("y", "").replace("h", "").split(",")
    # print(lst)
    try:
        x = int(file.split('_')[3].strip('x'))
    except:
        print(f'Unable to parse for {file}')
    y = int(filename.split('_')[4].split('.')[0].strip('y'))
    w, h = 512, 512
    mask[y:y+h, x:x+w, :] = cv2.imread( f"{mydir}/{file}",3)

contours = getContours(mask)
contoursColors = [{'cnt': contours, 'color': '255, 20, 20'}]

dsafid = {
    '32-2_PAS_1of2':'6691a0ba0519743b266f59c8'
}

slides2 = [
    '32-2_PAS_1of2'
]

annoooos = {}

for name in slides2:
    config = {
        'fid': dsafid[name],
        'username': 'manojkumargalla',
        'password': '3435isbcmon@G',
        'apiUrl': 'https://athena.rc.ufl.edu/api/v1',
        'layerName': 'tbm_geojson',
        'svsBase': "/blue/pinaki.sarder/nlucarelli/kpmp_new/"
    }

    annos = generateAnno(contoursColors)

    annoooos[name] = annos
    print('DONE GENERATING ANNOTATIONS!!!')

    dsa = DSA(config)

    fid = dsafid[name]

    annos = annoooos[name]
    dsa.postAnno(fid, annos)

# %%
# Example usage
filename = 'pred_img_0_25600x_33792y.png'
x, y = extract_coordinates(filename)
print(f'x = {x}, y = {y}')

# %%
filename = 'pred_img_0_25600x_33792y.png'

# %%
print(filename.split('x_'))

# %%
filename.split('_')[4].split('.')[0].strip('y')

# %%
import os
import cv2
import numpy as np
from modules.ftu import Tubule
from modules.slide import Slide
from modules.dsa import DSAFolder, DSAItem, DSA

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            # print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1]) 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)<len(cnts) and cnts[f+1][1][3]==-1: #No Children
                        pass
                    else: # Get Children
                        z = f+1
                        holes = []
                        while True:
                            hole = []
                            try:
                                cntChild = cnts[z][0]
                                hieChild = cnts[z][1]
                            except:
                                break
                            if hieChild[3]==-1:
                                break
                            for i in cntChild:
                                for j in i:
                                    x = int(j[0]) 
                                    y = int(j[1]) 
                                    hole.append([x, y, 0])
                            holes.append(hole)
                            z+=1
                        elem["holes"] = holes
                    elems.append(elem)

    anno = {
        "name": 'tbm_ai', 
        "description": 'tbm_ai',  
        "elements": None                        
    }
    anno["elements"] = elems
    annos.append(anno)

    return annos

# %%
import os
import cv2
import numpy as np
from modules.ftu import Tubule
from modules.slide import Slide
from modules.dsa import DSAFolder, DSAItem, DSA

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            # print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1]) 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)<len(cnts) and cnts[f+1][1][3]==-1: #No Children
                        pass
                    else: # Get Children
                        z = f+1
                        holes = []
                        while True:
                            hole = []
                            try:
                                cntChild = cnts[z][0]
                                hieChild = cnts[z][1]
                            except:
                                break
                            if hieChild[3]==-1:
                                break
                            for i in cntChild:
                                for j in i:
                                    x = int(j[0]) 
                                    y = int(j[1]) 
                                    hole.append([x, y, 0])
                            holes.append(hole)
                            z+=1
                        elem["holes"] = holes
                    elems.append(elem)

    anno = {
        "name": 'tbm_ai', 
        "description": 'tbm_ai',  
        "elements": None                        
    }
    anno["elements"] = elems
    annos.append(anno)

    return annos



def getContours(mask):

    def smoothBinary(mask2d):
        kn = 2
        iterat = 2
        kernel = np.ones((kn, kn), np.uint8) 
        for _ in range(iterat):
            mask2d = cv2.erode(mask2d, kernel, iterations=1) 
            mask2d = cv2.dilate(mask2d, kernel, iterations=1) 
        return mask2d
    
    mask2 = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    
    maskSmooth = smoothBinary(mask2)

    thresholdArea = 0.0001

    contours, hierarchy = cv2.findContours(maskSmooth, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    print(f"found {len(contours)} contours")

    c_max = max(contours, key = cv2.contourArea)
    area_min = cv2.contourArea(c_max) * thresholdArea
    
    print(len(contours))
    
    cntheis = sorted(zip(contours, hierarchy[0]), key=lambda b: cv2.contourArea(b[0]) , reverse=True)
    
    mxmx = int(1.0 * len(contours))
    
    contours_filtered = []
    
    for qq in range(mxmx):
        if qq%50==0:
            print(f"processing {qq}/{mxmx}")
        contour = cntheis[qq][0]
        hie = cntheis[qq][1]
        contours_filtered.append((contour,hie))

    return contours_filtered

# xx = 95663
# yy = 41940

xx = 129
yy = 61

mask = np.zeros((yy, xx, 3), dtype='uint8')

mydir = "/home/manojkumargalla/ResUNet/data/pred_512_jul15/S-1909-007149_PAS_1of2"

files = os.listdir(mydir)
print('Got the files!')
for file in files:
    # print(file)
    # lst = file.split('[')[-1].split(']')[0].replace("=", "").replace("x", "").replace("w", "").replace("y", "").replace("h", "").split(",")
    # print(lst)
    try:
        x = int(file.split('_')[3].strip('x'))
    except:
        print(f'Unable to parse for {file}')
    y = int(file.split('_')[4].split('.')[0].strip('y'))
    w, h = 512, 512
    # mask[y:y+h, x:x+w, :] = cv2.imread( f"{mydir}/{file}",3)
    img = cv2.imread( f"{mydir}/{file}",3)
    h, w, _ = img.shape
    if y + h <= yy and x + w <= xx:
        mask[y:y+h, x:x+w, :] = img
    else:
        print(f"Skipping tile {file} due to out-of-bounds placement.")
        print(f'y + h is {y+h}, x + w is {x+w}')
#     img = cv2.imread( f"{mydir}/{file}",3)
#     if img is None:
#         continue
    
#     img_resized = cv2.resize(img, (xx, yy))
#     mask = cv2.add(mask, img_resized)
    
print('Getting Contours')
contours = getContours(mask)
contoursColors = [{'cnt': contours, 'color': '255, 20, 20'}]

# dsafid = {
#     'S-1909-007149_PAS_1of2':'66918e4a0519743b266cee1b',
#     'S-1905-018731_PAS_2of2': '66946f630519743b266f75fa',
#     'S-1908-010066_PAS_1of2': '669473920519743b26705428',
#     '18-162_PAS_4of6':'6694760a0519743b2670d8e0',
#     'S-1905-017738_PAS_1of2':'66946ed40519743b266f75ee',
#     'S-2103-004857_PAS_2of2': '66951e5a0519743b267b8fa8',
#     'S-2106-003588_PAS_1of2': '66951e580519743b267b8fa5',
#     'S-1910-000089_PAS_2of2':  '66951fba0519743b267b8fea',
#     'S-2001-005357_PAS_1of2': '66951e5b0519743b267b8fab',
#     'S-1904-007293_PAS_1of2': '669520ca0519743b267cfe0a'
# }
dsafid = {
    'S-1909-007149_PAS_1of2':'66918e4a0519743b266cee1b'
}


# slides2 = [
#     'S-1909-007149_PAS_1of2',
#     'S-1905-018731_PAS_2of2',
#     'S-1908-010066_PAS_1of2',
#     '18-162_PAS_4of6',
#     'S-1905-017738_PAS_1of2',
#     'S-2103-004857_PAS_2of2',
#     'S-2106-003588_PAS_1of2',
#     'S-1910-000089_PAS_2of2',
#     'S-2001-005357_PAS_1of2',
#     'S-1904-007293_PAS_1of2'
# ]
slides2 = [
    'S-1909-007149_PAS_1of2'
]

annoooos = {}

for name in slides2:
    config = {
        'fid': dsafid[name],
        'username': 'manojkumargalla',
        'password': '3435isbcmon@G',
        'apiUrl': 'https://athena.rc.ufl.edu/api/v1',
        'layerName': 'tbm_geojson',
        'svsBase': "/blue/pinaki.sarder/nlucarelli/kpmp_new/"
    }
    print('Generating annos')
    annos = generateAnno(contoursColors)

    annoooos[name] = annos

    dsa = DSA(config)

    fid = dsafid[name]

    annos = annoooos[name]
    dsa.postAnno(fid, annos)

# %%
dsa.postAnno(fid, annos)

# %%
import os
mydir = "/home/manojkumargalla/ResUNet/data/pred_512_jul15/S-1909-007149_PAS_1of2"

files = os.listdir(mydir)
x_s=[]
y_s=[]
for file in files:
    x = int(file.split('_')[3].strip('x'))
    y= int(file.split('_')[4].split('.')[0].strip('y'))
    x_s.append(x)
    y_s.append(y)
print(min(x_s), max(x_s))
print(min(y_s), max(y_s))

# %%
6656/512

# %%
28672/13

# %%
with open('annos_output.txt', 'w') as file:
    file.write(str(annos))

# %%
li=[1,2,3]
a=str(li)
print(a)

# %%
import os
import cv2
import numpy as np
from modules.ftu import Tubule
from modules.slide import Slide
from modules.dsa import DSAFolder, DSAItem, DSA

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            # print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1]) 
                        points.append([x, y, 0])

                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)<len(cnts) and cnts[f+1][1][3]==-1: #No Children
                        pass
                    else: # Get Children
                        z = f+1
                        holes = []
                        while True:
                            hole = []
                            try:
                                cntChild = cnts[z][0]
                                hieChild = cnts[z][1]
                            except:
                                break
                            if hieChild[3]==-1:
                                break
                            for i in cntChild:
                                for j in i:
                                    x = int(j[0]) 
                                    y = int(j[1]) 
                                    hole.append([x, y, 0])
                            holes.append(hole)
                            z+=1
                        elem["holes"] = holes
                    elems.append(elem)

    anno = {
        "name": 'tbm_ai_filtered', 
        "description": 'tbm_ai_filtered',  
        "elements": None                        
    }
    anno["elements"] = elems
    annos.append(anno)

    return annos



def getContours(mask):

    def smoothBinary(mask2d):
        kn = 2
        iterat = 2
        kernel = np.ones((kn, kn), np.uint8) 
        for _ in range(iterat):
            mask2d = cv2.erode(mask2d, kernel, iterations=1) 
            mask2d = cv2.dilate(mask2d, kernel, iterations=1) 
        return mask2d
    
    mask2 = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    
    maskSmooth = smoothBinary(mask2)

    thresholdArea = 0.0001

    contours, hierarchy = cv2.findContours(maskSmooth, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    print(f"found {len(contours)} contours")

    c_max = max(contours, key = cv2.contourArea)
    area_min = cv2.contourArea(c_max) * thresholdArea
    
    print(len(contours))
    
    cntheis = sorted(zip(contours, hierarchy[0]), key=lambda b: cv2.contourArea(b[0]) , reverse=True)
    
    mxmx = int(1.0 * len(contours))
    
    contours_filtered = []
    
    for qq in range(mxmx):
        if qq%50==0:
            print(f"processing {qq}/{mxmx}")
        contour = cntheis[qq][0]
        hie = cntheis[qq][1]
        contours_filtered.append((contour,hie))

    return contours_filtered

xx = 35873
yy = 58561

mask = np.zeros((yy, xx, 3), dtype='uint8')

mydir = "/blue/pinaki.sarder/manojkumargalla/filtered_image_tiles/filtered_image/"

files = os.listdir(mydir)

for file in files:
    # lst = file.split('[')[-1].split(']')[0].replace("=", "").replace("x", "").replace("w", "").replace("y", "").replace("h", "").split(",")
    # print(lst)
    print(file)
    x = int(file.split('_')[0].strip('x'))
    # x, y, w, h = [int(k) for k in lst]
    y = int(file.split('_')[1].split('.')[0].strip('y'))
    w, h = 512, 512
    # mask[y:y+h, x:x+w, :] = cv2.imread( f"{mydir}/{file}",3)
    img = cv2.imread( f"{mydir}/{file}",3)
    h, w, _ = img.shape
    if y + h <= yy and x + w <= xx:
        mask[y:y+h, x:x+w, :] = img
    else:
        print(f"Skipping tile {file} due to out-of-bounds placement.")
        print(f'y + h is {y+h}, x + w is {x+w}')

contours = getContours(mask)
contoursColors = [{'cnt': contours, 'color': '255, 20, 20'}]

dsafid = {
    '32-2_PAS_1of2':'6691a0ba0519743b266f59c8'
}

slides2 = [
    '32-2_PAS_1of2'
]

annoooos = {}

for name in slides2:
    config = {
        'fid': dsafid[name],
        'username': 'manojkumargalla',
        'password': '3435isbcmon@G',
        'apiUrl': 'https://athena.rc.ufl.edu/api/v1',
        'layerName': 'tbm_geojson',
        'svsBase': "/blue/pinaki.sarder/nlucarelli/kpmp_new/"
    }

    annos = generateAnno(contoursColors)

    annoooos[name] = annos

    dsa = DSA(config)

    fid = dsafid[name]

    annos = annoooos[name]
    dsa.postAnno(fid, annos)
# Out:
# 11264x_24064y.png
# 19456x_12800y.png
# 25088x_41984y.png
# 17920x_18944y.png
# 21504x_46592y.png
# 16384x_50688y.png
# 15872x_19456y.png
# 17408x_19456y.png
# 19456x_47616y.png
# 08704x_52736y.png
# 18944x_44544y.png
# 10752x_53248y.png
# 23552x_44544y.png
# 11776x_21504y.png
# 24576x_43520y.png
# 19456x_14848y.png
# 18944x_47104y.png
# 14336x_52224y.png
# 13312x_19968y.png
# 09728x_53248y.png
# 19456x_15360y.png
# 16896x_46080y.png
# 16384x_17408y.png
# 13824x_50176y.png
# 18944x_45568y.png
# 08192x_27136y.png
# 14848x_18944y.png
# 09216x_28160y.png
# 07680x_28672y.png
# 25600x_41472y.png
# 18944x_46592y.png
# 17408x_50176y.png
# 11264x_23552y.png
# 13824x_52224y.png
# 24576x_41472y.png
# 14848x_22016y.png
# 23040x_44032y.png
# 19968x_12288y.png
# 15360x_17920y.png
# 17408x_46080y.png
# 11776x_50688y.png
# 14848x_50176y.png
# 07168x_26112y.png
# 18944x_49152y.png
# 16384x_16896y.png
# 18944x_47616y.png
# 09728x_27648y.png
# 18944x_48128y.png
# 18944x_46080y.png
# 13312x_22016y.png
# 14848x_49152y.png
# 09216x_52736y.png
# 14848x_18432y.png
# 17408x_14848y.png
# 23552x_43008y.png
# 16896x_46592y.png
# 20480x_46080y.png
# 09728x_52736y.png
# 15360x_22016y.png
# 11264x_50688y.png
# 19968x_14336y.png
# 16896x_16896y.png
# 17920x_46592y.png
# 17408x_18432y.png
# 08192x_25600y.png
# 20480x_13312y.png
# 18432x_49664y.png
# 14336x_19456y.png
# 16896x_50688y.png
# 19456x_11776y.png
# 24576x_42496y.png
# 17920x_47616y.png
# 19456x_47104y.png
# 13824x_51200y.png
# 22528x_45568y.png
# 20992x_44544y.png
# 14336x_51200y.png
# 11776x_50176y.png
# 16384x_15360y.png
# 12800x_22016y.png
# 12800x_19968y.png
# 25600x_41984y.png
# 14336x_48640y.png
# 07168x_28672y.png
# 18432x_17408y.png
# 11264x_26112y.png
# 09728x_28160y.png
# 26624x_40960y.png
# 15872x_49152y.png
# 17408x_15872y.png
# 15872x_50176y.png
# 10752x_27136y.png
# 14848x_47616y.png
# 16384x_18432y.png
# 17920x_49152y.png
# 24576x_41984y.png
# 13824x_23552y.png
# 10240x_51200y.png
# 22528x_43520y.png
# 09216x_27648y.png
# 07680x_28160y.png
# 19968x_11264y.png
# 24576x_44032y.png
# 11264x_25600y.png
# 14336x_17920y.png
# 07680x_27136y.png
# 20480x_47104y.png
# 13312x_24064y.png
# 22016x_45568y.png
# 16384x_49664y.png
# 21504x_46080y.png
# 18432x_14848y.png
# 17920x_45056y.png
# 15360x_18944y.png
# 19968x_11776y.png
# 09728x_53760y.png
# 11776x_25600y.png
# 09216x_24064y.png
# 18432x_12800y.png
# 15360x_17408y.png
# 10752x_51200y.png
# 14336x_49152y.png
# 18944x_14848y.png
# 18432x_14336y.png
# 13312x_51200y.png
# 08704x_24576y.png
# 21504x_44032y.png
# 20480x_47616y.png
# 15872x_16896y.png
# 23552x_44032y.png
# 19456x_13312y.png
# 08704x_28672y.png
# 15872x_17920y.png
# 18432x_45568y.png
# 21504x_43008y.png
# 13312x_22528y.png
# 19456x_15872y.png
# 17408x_13824y.png
# 17920x_48640y.png
# 16384x_50176y.png
# 17920x_49664y.png
# 13824x_19456y.png
# 20992x_14336y.png
# 25088x_41472y.png
# 08704x_27648y.png
# 17408x_47616y.png
# 11264x_51200y.png
# 10240x_25088y.png
# 14848x_20480y.png
# 18432x_13824y.png
# 14336x_24064y.png
# 12800x_52736y.png
# 25088x_43008y.png
# 14848x_51200y.png
# 18432x_47616y.png
# 12288x_50688y.png
# 20480x_48128y.png
# 12800x_51200y.png
# 16896x_15360y.png
# 13824x_48640y.png
# 15360x_51712y.png
# 08704x_53248y.png
# 18944x_12288y.png
# 13824x_20992y.png
# 18944x_15360y.png
# 10240x_26112y.png
# 20992x_46080y.png
# 12800x_50176y.png
# 09728x_28672y.png
# 18944x_45056y.png
# 10240x_24576y.png
# 19456x_48128y.png
# 24064x_41984y.png
# 19968x_13824y.png
# 12288x_23552y.png
# 12288x_20992y.png
# 10752x_54272y.png
# 13824x_22016y.png
# 10752x_26624y.png
# 20480x_12800y.png
# 11264x_52736y.png
# 19968x_46080y.png
# 13824x_20480y.png
# 14336x_22016y.png
# 23040x_42496y.png
# 20992x_14848y.png
# 18944x_12800y.png
# 07168x_27648y.png
# 25600x_40448y.png
# 16896x_19456y.png
# 11264x_26624y.png
# 22016x_42496y.png
# 26112x_40960y.png
# 08192x_26112y.png
# 20480x_45056y.png
# 10752x_52224y.png
# 11264x_22016y.png
# 15360x_20992y.png
# 13312x_52224y.png
# 19968x_45056y.png
# 13312x_50176y.png
# 16384x_49152y.png
# 08704x_25600y.png
# 10240x_28672y.png
# 14336x_50688y.png
# 18944x_15872y.png
# 07680x_27648y.png
# 19968x_15360y.png
# 10752x_27648y.png
# 09216x_50688y.png
# 11776x_25088y.png
# 12288x_22528y.png
# 12800x_49152y.png
# 09216x_51712y.png
# 11776x_53760y.png
# 18944x_13824y.png
# 14336x_22528y.png
# 17408x_48640y.png
# 08192x_26624y.png
# 25088x_40448y.png
# 12288x_25600y.png
# 14336x_51712y.png
# 11776x_26624y.png
# 15872x_18944y.png
# 22016x_46592y.png
# 15360x_48128y.png
# 13312x_51712y.png
# 16384x_16384y.png
# 07680x_26112y.png
# 13824x_50688y.png
# 11264x_23040y.png
# 12800x_52224y.png
# 15872x_15872y.png
# 16384x_18944y.png
# 18944x_14336y.png
# 18432x_47104y.png
# 07168x_28160y.png
# 08704x_29184y.png
# 10752x_23552y.png
# 22528x_45056y.png
# 21504x_42496y.png
# 19968x_44032y.png
# 16896x_18432y.png
# 16896x_17408y.png
# 26112x_41472y.png
# 20480x_43520y.png
# 25600x_43008y.png
# 14848x_49664y.png
# 15872x_20480y.png
# 10240x_25600y.png
# 20992x_13312y.png
# 12800x_24064y.png
# 15360x_21504y.png
# 16896x_50176y.png
# 20992x_45568y.png
# 24576x_40448y.png
# 10752x_52736y.png
# 13824x_23040y.png
# 19456x_14336y.png
# 10240x_53760y.png
# 09216x_28672y.png
# 11776x_24064y.png
# 21504x_47104y.png
# 16384x_19456y.png
# 11264x_52224y.png
# 09216x_29184y.png
# 13312x_48640y.png
# 24064x_43008y.png
# 19456x_13824y.png
# 23040x_43520y.png
# 19456x_16384y.png
# 19456x_45568y.png
# 12288x_49664y.png
# 21504x_12800y.png
# 17408x_49664y.png
# 16384x_15872y.png
# 15360x_49664y.png
# 13312x_23552y.png
# 14336x_19968y.png
# 09216x_53248y.png
# 16384x_20992y.png
# 16384x_48128y.png
# 10752x_50176y.png
# 15360x_48640y.png
# 10752x_24576y.png
# 16384x_20480y.png
# 16896x_16384y.png
# 08192x_28672y.png
# 22528x_46592y.png
# 20992x_12800y.png
# 20480x_11776y.png
# 16896x_14336y.png
# 13824x_51712y.png
# 13824x_52736y.png
# 12288x_51200y.png
# 23040x_41472y.png
# 16896x_18944y.png
# 13824x_18432y.png
# 12288x_49152y.png
# 15360x_20480y.png
# 15360x_18432y.png
# 17920x_47104y.png
# 18432x_48640y.png
# 15872x_18432y.png
# 17408x_48128y.png
# 17920x_18432y.png
# 08192x_29696y.png
# 08704x_26112y.png
# 18432x_49152y.png
# 11264x_25088y.png
# 12800x_53248y.png
# 08704x_27136y.png
# 08192x_28160y.png
# 11776x_52224y.png
# 19968x_15872y.png
# 26112x_39936y.png
# 06656x_27136y.png
# 15872x_16384y.png
# 13312x_20480y.png
# 19968x_48128y.png
# 18944x_48640y.png
# 19968x_46592y.png
# 12288x_52736y.png
# 18944x_16384y.png
# 10240x_51712y.png
# 14848x_48640y.png
# 16896x_49152y.png
# 13312x_50688y.png
# 18432x_15872y.png
# 10752x_22528y.png
# 26624x_41472y.png
# 23552x_41472y.png
# 14336x_21504y.png
# 11776x_52736y.png
# 09728x_25088y.png
# 09216x_27136y.png
# 10240x_27648y.png
# 12288x_22016y.png
# 09728x_52224y.png
# 12288x_24576y.png
# 15872x_49664y.png
# 24064x_43520y.png
# 15360x_51200y.png
# 16384x_47104y.png
# 14336x_49664y.png
# 14336x_48128y.png
# 19456x_45056y.png
# 14336x_18944y.png
# 13824x_24576y.png
# 19456x_12288y.png
# 18432x_13312y.png
# 19456x_44544y.png
# 15360x_19456y.png
# 17920x_13312y.png
# 14848x_21504y.png
# 09216x_26112y.png
# 12288x_50176y.png
# 17408x_17408y.png
# 20992x_45056y.png
# 09728x_23552y.png
# 09728x_26112y.png
# 12800x_20992y.png
# 16896x_20480y.png
# 25088x_40960y.png
# 14336x_50176y.png
# 18432x_15360y.png
# 11776x_49664y.png
# 12288x_53248y.png
# 15360x_49152y.png
# 13312x_24576y.png
# 16384x_46592y.png
# 23040x_43008y.png
# 11776x_51200y.png
# 13824x_18944y.png
# 12800x_50688y.png
# 17408x_18944y.png
# 16896x_47104y.png
# 12288x_20480y.png
# 17408x_47104y.png
# 11776x_23040y.png
# 10752x_28160y.png
# 08192x_27648y.png
# 17408x_16384y.png
# 09728x_27136y.png
# 13312x_23040y.png
# 20480x_13824y.png
# 12800x_23552y.png
# 11776x_26112y.png
# 17920x_48128y.png
# 10752x_51712y.png
# 17408x_45568y.png
# 20480x_44032y.png
# 23552x_42496y.png
# 16896x_49664y.png
# 14848x_20992y.png
# 21504x_44544y.png
# 17408x_17920y.png
# 20480x_14848y.png
# 08192x_25088y.png
# 23040x_41984y.png
# 09728x_51712y.png
# 10240x_50176y.png
# 14848x_51712y.png
# 19968x_45568y.png
# 17408x_19968y.png
# 24064x_44032y.png
# 08192x_29184y.png
# 20992x_44032y.png
# 17920x_13824y.png
# 14336x_18432y.png
# 15872x_17408y.png
# 16896x_47616y.png
# 19456x_46592y.png
# 13824x_24064y.png
# 15872x_20992y.png
# 10240x_23040y.png
# 11264x_22528y.png
# 07680x_26624y.png
# 10240x_27136y.png
# 09216x_51200y.png
# 11264x_54272y.png
# 15872x_50688y.png
# 12288x_51712y.png
# 15872x_47616y.png
# 20480x_46592y.png
# 12800x_21504y.png
# 11776x_23552y.png
# 19456x_46080y.png
# 07168x_26624y.png
# 19456x_48640y.png
# 21504x_43520y.png
# 13312x_21504y.png
# 10752x_24064y.png
# 14848x_52224y.png
# 21504x_45056y.png
# 11264x_50176y.png
# 10752x_23040y.png
# 21504x_45568y.png
# 22528x_42496y.png
# 13824x_21504y.png
# 20992x_43008y.png
# 17920x_16896y.png
# 24576x_43008y.png
# 15360x_47616y.png
# 10752x_50688y.png
# 17920x_14848y.png
# 15360x_19968y.png
# 12800x_20480y.png
# 23040x_45056y.png
# 15360x_16896y.png
# 16384x_48640y.png
# 09728x_54272y.png
# 10240x_26624y.png
# 07680x_25600y.png
# 11776x_53248y.png
# 18432x_45056y.png
# 20992x_47616y.png
# 24064x_44544y.png
# 23040x_44544y.png
# 09216x_24576y.png
# 11776x_24576y.png
# 17920x_14336y.png
# 12288x_23040y.png
# 20992x_47104y.png
# 13312x_19456y.png
# 25600x_39936y.png
# 17920x_17920y.png
# 14336x_20992y.png
# 14336x_23552y.png
# 25600x_42496y.png
# 10240x_54272y.png
# 15360x_47104y.png
# 25088x_42496y.png
# 25600x_40960y.png
# 15360x_50176y.png
# 20480x_44544y.png
# 22016x_46080y.png
# 15360x_22528y.png
# 19968x_47616y.png
# 09216x_52224y.png
# 16896x_19968y.png
# 14848x_22528y.png
# 23552x_43520y.png
# 10752x_53760y.png
# 12288x_26112y.png
# 10752x_25088y.png
# 19968x_44544y.png
# 09728x_50688y.png
# 20480x_12288y.png
# 12288x_25088y.png
# 12800x_23040y.png
# 15872x_46592y.png
# 16896x_14848y.png
# 24064x_40960y.png
# 07680x_29184y.png
# 24064x_41472y.png
# 11264x_24576y.png
# 09216x_25088y.png
# 18432x_46080y.png
# 13312x_49664y.png
# 20480x_14336y.png
# 09216x_25600y.png
# 19968x_47104y.png
# 11264x_53760y.png
# 17920x_16384y.png
# 26112x_41984y.png
# 08704x_25088y.png
# 11776x_22528y.png
# 19968x_12800y.png
# 14848x_50688y.png
# 14848x_17408y.png
# 12288x_24064y.png
# 16384x_19968y.png
# 19968x_13312y.png
# 14848x_19456y.png
# 16384x_47616y.png
# 16896x_48640y.png
# 10752x_25600y.png
# 17408x_16896y.png
# 08704x_29696y.png
# 22528x_44544y.png
# 20992x_43520y.png
# 12800x_22528y.png
# 17920x_15872y.png
# 13824x_22528y.png
# 18944x_13312y.png
# 09216x_26624y.png
# 17920x_17408y.png
# 09728x_24064y.png
# 22528x_43008y.png
# 22016x_43520y.png
# 10240x_52736y.png
# 12800x_49664y.png
# 18432x_17920y.png
# 10240x_28160y.png
# 09728x_51200y.png
# 13824x_19968y.png
# 16896x_48128y.png
# 07168x_27136y.png
# 20480x_45568y.png
# 14848x_19968y.png
# 17408x_15360y.png
# 11264x_27648y.png
# 10752x_26112y.png
# 10240x_23552y.png
# 10240x_50688y.png
# 26624x_41984y.png
# 08704x_51712y.png
# 18432x_48128y.png
# 22528x_46080y.png
# 26112x_40448y.png
# 09728x_26624y.png
# 17408x_14336y.png
# 11264x_51712y.png
# 08704x_26624y.png
# 22016x_45056y.png
# 11776x_20992y.png
# 17408x_46592y.png
# 15872x_48640y.png
# 11776x_51712y.png
# 18432x_46592y.png
# 12800x_25088y.png
# 13312x_49152y.png
# 09728x_24576y.png
# 24064x_42496y.png
# 12800x_25600y.png
# 15872x_47104y.png
# 13824x_49152y.png
# 17920x_45568y.png
# 12800x_51712y.png
# 16896x_20992y.png
# 22016x_43008y.png
# 11264x_53248y.png
# 15872x_48128y.png
# 17920x_46080y.png
# 20992x_46592y.png
# 15872x_51200y.png
# 24576x_40960y.png
# 23552x_41984y.png
# 13312x_20992y.png
# 11264x_49664y.png
# 10240x_52224y.png
# 09728x_25600y.png
# 22016x_44544y.png
# 18432x_18432y.png
# 12288x_52224y.png
# 14848x_23040y.png
# 08704x_28160y.png
# 16896x_17920y.png
# 13312x_18944y.png
# 13824x_49664y.png
# 16896x_15872y.png
# 13824x_48128y.png
# 17408x_49152y.png
# 09216x_53760y.png
# 20992x_12288y.png
# 14848x_17920y.png
# 22528x_44032y.png
# 15872x_19968y.png
# 22016x_44032y.png
# 16384x_17920y.png
# 14336x_23040y.png
# 15872x_21504y.png
# 18432x_16384y.png
# 13312x_25088y.png
# 21504x_13312y.png
# 22528x_41984y.png
# 18432x_16896y.png
# 17920x_15360y.png
# 25600x_43520y.png
# 14336x_20480y.png
# 10240x_24064y.png
# 12288x_21504y.png
# 10240x_53248y.png
# found 39406 contours
# 39406
# processing 0/39406
# processing 50/39406
# processing 100/39406
# processing 150/39406
# processing 200/39406
# processing 250/39406
# processing 300/39406
# processing 350/39406
# processing 400/39406
# processing 450/39406
# processing 500/39406
# processing 550/39406
# processing 600/39406
# processing 650/39406
# processing 700/39406
# processing 750/39406
# processing 800/39406
# processing 850/39406
# processing 900/39406
# processing 950/39406
# processing 1000/39406
# processing 1050/39406
# processing 1100/39406
# processing 1150/39406
# processing 1200/39406
# processing 1250/39406
# processing 1300/39406
# processing 1350/39406
# processing 1400/39406
# processing 1450/39406
# processing 1500/39406
# processing 1550/39406
# processing 1600/39406
# processing 1650/39406
# processing 1700/39406
# processing 1750/39406
# processing 1800/39406
# processing 1850/39406
# processing 1900/39406
# processing 1950/39406
# processing 2000/39406
# processing 2050/39406
# processing 2100/39406
# processing 2150/39406
# processing 2200/39406
# processing 2250/39406
# processing 2300/39406
# processing 2350/39406
# processing 2400/39406
# processing 2450/39406
# processing 2500/39406
# processing 2550/39406
# processing 2600/39406
# processing 2650/39406
# processing 2700/39406
# processing 2750/39406
# processing 2800/39406
# processing 2850/39406
# processing 2900/39406
# processing 2950/39406
# processing 3000/39406
# processing 3050/39406
# processing 3100/39406
# processing 3150/39406
# processing 3200/39406
# processing 3250/39406
# processing 3300/39406
# processing 3350/39406
# processing 3400/39406
# processing 3450/39406
# processing 3500/39406
# processing 3550/39406
# processing 3600/39406
# processing 3650/39406
# processing 3700/39406
# processing 3750/39406
# processing 3800/39406
# processing 3850/39406
# processing 3900/39406
# processing 3950/39406
# processing 4000/39406
# processing 4050/39406
# processing 4100/39406
# processing 4150/39406
# processing 4200/39406
# processing 4250/39406
# processing 4300/39406
# processing 4350/39406
# processing 4400/39406
# processing 4450/39406
# processing 4500/39406
# processing 4550/39406
# processing 4600/39406
# processing 4650/39406
# processing 4700/39406
# processing 4750/39406
# processing 4800/39406
# processing 4850/39406
# processing 4900/39406
# processing 4950/39406
# processing 5000/39406
# processing 5050/39406
# processing 5100/39406
# processing 5150/39406
# processing 5200/39406
# processing 5250/39406
# processing 5300/39406
# processing 5350/39406
# processing 5400/39406
# processing 5450/39406
# processing 5500/39406
# processing 5550/39406
# processing 5600/39406
# processing 5650/39406
# processing 5700/39406
# processing 5750/39406
# processing 5800/39406
# processing 5850/39406
# processing 5900/39406
# processing 5950/39406
# processing 6000/39406
# processing 6050/39406
# processing 6100/39406
# processing 6150/39406
# processing 6200/39406
# processing 6250/39406
# processing 6300/39406
# processing 6350/39406
# processing 6400/39406
# processing 6450/39406
# processing 6500/39406
# processing 6550/39406
# processing 6600/39406
# processing 6650/39406
# processing 6700/39406
# processing 6750/39406
# processing 6800/39406
# processing 6850/39406
# processing 6900/39406
# processing 6950/39406
# processing 7000/39406
# processing 7050/39406
# processing 7100/39406
# processing 7150/39406
# processing 7200/39406
# processing 7250/39406
# processing 7300/39406
# processing 7350/39406
# processing 7400/39406
# processing 7450/39406
# processing 7500/39406
# processing 7550/39406
# processing 7600/39406
# processing 7650/39406
# processing 7700/39406
# processing 7750/39406
# processing 7800/39406
# processing 7850/39406
# processing 7900/39406
# processing 7950/39406
# processing 8000/39406
# processing 8050/39406
# processing 8100/39406
# processing 8150/39406
# processing 8200/39406
# processing 8250/39406
# processing 8300/39406
# processing 8350/39406
# processing 8400/39406
# processing 8450/39406
# processing 8500/39406
# processing 8550/39406
# processing 8600/39406
# processing 8650/39406
# processing 8700/39406
# processing 8750/39406
# processing 8800/39406
# processing 8850/39406
# processing 8900/39406
# processing 8950/39406
# processing 9000/39406
# processing 9050/39406
# processing 9100/39406
# processing 9150/39406
# processing 9200/39406
# processing 9250/39406
# processing 9300/39406
# processing 9350/39406
# processing 9400/39406
# processing 9450/39406
# processing 9500/39406
# processing 9550/39406
# processing 9600/39406
# processing 9650/39406
# processing 9700/39406
# processing 9750/39406
# processing 9800/39406
# processing 9850/39406
# processing 9900/39406
# processing 9950/39406
# processing 10000/39406
# processing 10050/39406
# processing 10100/39406
# processing 10150/39406
# processing 10200/39406
# processing 10250/39406
# processing 10300/39406
# processing 10350/39406
# processing 10400/39406
# processing 10450/39406
# processing 10500/39406
# processing 10550/39406
# processing 10600/39406
# processing 10650/39406
# processing 10700/39406
# processing 10750/39406
# processing 10800/39406
# processing 10850/39406
# processing 10900/39406
# processing 10950/39406
# processing 11000/39406
# processing 11050/39406
# processing 11100/39406
# processing 11150/39406
# processing 11200/39406
# processing 11250/39406
# processing 11300/39406
# processing 11350/39406
# processing 11400/39406
# processing 11450/39406
# processing 11500/39406
# processing 11550/39406
# processing 11600/39406
# processing 11650/39406
# processing 11700/39406
# processing 11750/39406
# processing 11800/39406
# processing 11850/39406
# processing 11900/39406
# processing 11950/39406
# processing 12000/39406
# processing 12050/39406
# processing 12100/39406
# processing 12150/39406
# processing 12200/39406
# processing 12250/39406
# processing 12300/39406
# processing 12350/39406
# processing 12400/39406
# processing 12450/39406
# processing 12500/39406
# processing 12550/39406
# processing 12600/39406
# processing 12650/39406
# processing 12700/39406
# processing 12750/39406
# processing 12800/39406
# processing 12850/39406
# processing 12900/39406
# processing 12950/39406
# processing 13000/39406
# processing 13050/39406
# processing 13100/39406
# processing 13150/39406
# processing 13200/39406
# processing 13250/39406
# processing 13300/39406
# processing 13350/39406
# processing 13400/39406
# processing 13450/39406
# processing 13500/39406
# processing 13550/39406
# processing 13600/39406
# processing 13650/39406
# processing 13700/39406
# processing 13750/39406
# processing 13800/39406
# processing 13850/39406
# processing 13900/39406
# processing 13950/39406
# processing 14000/39406
# processing 14050/39406
# processing 14100/39406
# processing 14150/39406
# processing 14200/39406
# processing 14250/39406
# processing 14300/39406
# processing 14350/39406
# processing 14400/39406
# processing 14450/39406
# processing 14500/39406
# processing 14550/39406
# processing 14600/39406
# processing 14650/39406
# processing 14700/39406
# processing 14750/39406
# processing 14800/39406
# processing 14850/39406
# processing 14900/39406
# processing 14950/39406
# processing 15000/39406
# processing 15050/39406
# processing 15100/39406
# processing 15150/39406
# processing 15200/39406
# processing 15250/39406
# processing 15300/39406
# processing 15350/39406
# processing 15400/39406
# processing 15450/39406
# processing 15500/39406
# processing 15550/39406
# processing 15600/39406
# processing 15650/39406
# processing 15700/39406
# processing 15750/39406
# processing 15800/39406
# processing 15850/39406
# processing 15900/39406
# processing 15950/39406
# processing 16000/39406
# processing 16050/39406
# processing 16100/39406
# processing 16150/39406
# processing 16200/39406
# processing 16250/39406
# processing 16300/39406
# processing 16350/39406
# processing 16400/39406
# processing 16450/39406
# processing 16500/39406
# processing 16550/39406
# processing 16600/39406
# processing 16650/39406
# processing 16700/39406
# processing 16750/39406
# processing 16800/39406
# processing 16850/39406
# processing 16900/39406
# processing 16950/39406
# processing 17000/39406
# processing 17050/39406
# processing 17100/39406
# processing 17150/39406
# processing 17200/39406
# processing 17250/39406
# processing 17300/39406
# processing 17350/39406
# processing 17400/39406
# processing 17450/39406
# processing 17500/39406
# processing 17550/39406
# processing 17600/39406
# processing 17650/39406
# processing 17700/39406
# processing 17750/39406
# processing 17800/39406
# processing 17850/39406
# processing 17900/39406
# processing 17950/39406
# processing 18000/39406
# processing 18050/39406
# processing 18100/39406
# processing 18150/39406
# processing 18200/39406
# processing 18250/39406
# processing 18300/39406
# processing 18350/39406
# processing 18400/39406
# processing 18450/39406
# processing 18500/39406
# processing 18550/39406
# processing 18600/39406
# processing 18650/39406
# processing 18700/39406
# processing 18750/39406
# processing 18800/39406
# processing 18850/39406
# processing 18900/39406
# processing 18950/39406
# processing 19000/39406
# processing 19050/39406
# processing 19100/39406
# processing 19150/39406
# processing 19200/39406
# processing 19250/39406
# processing 19300/39406
# processing 19350/39406
# processing 19400/39406
# processing 19450/39406
# processing 19500/39406
# processing 19550/39406
# processing 19600/39406
# processing 19650/39406
# processing 19700/39406
# processing 19750/39406
# processing 19800/39406
# processing 19850/39406
# processing 19900/39406
# processing 19950/39406
# processing 20000/39406
# processing 20050/39406
# processing 20100/39406
# processing 20150/39406
# processing 20200/39406
# processing 20250/39406
# processing 20300/39406
# processing 20350/39406
# processing 20400/39406
# processing 20450/39406
# processing 20500/39406
# processing 20550/39406
# processing 20600/39406
# processing 20650/39406
# processing 20700/39406
# processing 20750/39406
# processing 20800/39406
# processing 20850/39406
# processing 20900/39406
# processing 20950/39406
# processing 21000/39406
# processing 21050/39406
# processing 21100/39406
# processing 21150/39406
# processing 21200/39406
# processing 21250/39406
# processing 21300/39406
# processing 21350/39406
# processing 21400/39406
# processing 21450/39406
# processing 21500/39406
# processing 21550/39406
# processing 21600/39406
# processing 21650/39406
# processing 21700/39406
# processing 21750/39406
# processing 21800/39406
# processing 21850/39406
# processing 21900/39406
# processing 21950/39406
# processing 22000/39406
# processing 22050/39406
# processing 22100/39406
# processing 22150/39406
# processing 22200/39406
# processing 22250/39406
# processing 22300/39406
# processing 22350/39406
# processing 22400/39406
# processing 22450/39406
# processing 22500/39406
# processing 22550/39406
# processing 22600/39406
# processing 22650/39406
# processing 22700/39406
# processing 22750/39406
# processing 22800/39406
# processing 22850/39406
# processing 22900/39406
# processing 22950/39406
# processing 23000/39406
# processing 23050/39406
# processing 23100/39406
# processing 23150/39406
# processing 23200/39406
# processing 23250/39406
# processing 23300/39406
# processing 23350/39406
# processing 23400/39406
# processing 23450/39406
# processing 23500/39406
# processing 23550/39406
# processing 23600/39406
# processing 23650/39406
# processing 23700/39406
# processing 23750/39406
# processing 23800/39406
# processing 23850/39406
# processing 23900/39406
# processing 23950/39406
# processing 24000/39406
# processing 24050/39406
# processing 24100/39406
# processing 24150/39406
# processing 24200/39406
# processing 24250/39406
# processing 24300/39406
# processing 24350/39406
# processing 24400/39406
# processing 24450/39406
# processing 24500/39406
# processing 24550/39406
# processing 24600/39406
# processing 24650/39406
# processing 24700/39406
# processing 24750/39406
# processing 24800/39406
# processing 24850/39406
# processing 24900/39406
# processing 24950/39406
# processing 25000/39406
# processing 25050/39406
# processing 25100/39406
# processing 25150/39406
# processing 25200/39406
# processing 25250/39406
# processing 25300/39406
# processing 25350/39406
# processing 25400/39406
# processing 25450/39406
# processing 25500/39406
# processing 25550/39406
# processing 25600/39406
# processing 25650/39406
# processing 25700/39406
# processing 25750/39406
# processing 25800/39406
# processing 25850/39406
# processing 25900/39406
# processing 25950/39406
# processing 26000/39406
# processing 26050/39406
# processing 26100/39406
# processing 26150/39406
# processing 26200/39406
# processing 26250/39406
# processing 26300/39406
# processing 26350/39406
# processing 26400/39406
# processing 26450/39406
# processing 26500/39406
# processing 26550/39406
# processing 26600/39406
# processing 26650/39406
# processing 26700/39406
# processing 26750/39406
# processing 26800/39406
# processing 26850/39406
# processing 26900/39406
# processing 26950/39406
# processing 27000/39406
# processing 27050/39406
# processing 27100/39406
# processing 27150/39406
# processing 27200/39406
# processing 27250/39406
# processing 27300/39406
# processing 27350/39406
# processing 27400/39406
# processing 27450/39406
# processing 27500/39406
# processing 27550/39406
# processing 27600/39406
# processing 27650/39406
# processing 27700/39406
# processing 27750/39406
# processing 27800/39406
# processing 27850/39406
# processing 27900/39406
# processing 27950/39406
# processing 28000/39406
# processing 28050/39406
# processing 28100/39406
# processing 28150/39406
# processing 28200/39406
# processing 28250/39406
# processing 28300/39406
# processing 28350/39406
# processing 28400/39406
# processing 28450/39406
# processing 28500/39406
# processing 28550/39406
# processing 28600/39406
# processing 28650/39406
# processing 28700/39406
# processing 28750/39406
# processing 28800/39406
# processing 28850/39406
# processing 28900/39406
# processing 28950/39406
# processing 29000/39406
# processing 29050/39406
# processing 29100/39406
# processing 29150/39406
# processing 29200/39406
# processing 29250/39406
# processing 29300/39406
# processing 29350/39406
# processing 29400/39406
# processing 29450/39406
# processing 29500/39406
# processing 29550/39406
# processing 29600/39406
# processing 29650/39406
# processing 29700/39406
# processing 29750/39406
# processing 29800/39406
# processing 29850/39406
# processing 29900/39406
# processing 29950/39406
# processing 30000/39406
# processing 30050/39406
# processing 30100/39406
# processing 30150/39406
# processing 30200/39406
# processing 30250/39406
# processing 30300/39406
# processing 30350/39406
# processing 30400/39406
# processing 30450/39406
# processing 30500/39406
# processing 30550/39406
# processing 30600/39406
# processing 30650/39406
# processing 30700/39406
# processing 30750/39406
# processing 30800/39406
# processing 30850/39406
# processing 30900/39406
# processing 30950/39406
# processing 31000/39406
# processing 31050/39406
# processing 31100/39406
# processing 31150/39406
# processing 31200/39406
# processing 31250/39406
# processing 31300/39406
# processing 31350/39406
# processing 31400/39406
# processing 31450/39406
# processing 31500/39406
# processing 31550/39406
# processing 31600/39406
# processing 31650/39406
# processing 31700/39406
# processing 31750/39406
# processing 31800/39406
# processing 31850/39406
# processing 31900/39406
# processing 31950/39406
# processing 32000/39406
# processing 32050/39406
# processing 32100/39406
# processing 32150/39406
# processing 32200/39406
# processing 32250/39406
# processing 32300/39406
# processing 32350/39406
# processing 32400/39406
# processing 32450/39406
# processing 32500/39406
# processing 32550/39406
# processing 32600/39406
# processing 32650/39406
# processing 32700/39406
# processing 32750/39406
# processing 32800/39406
# processing 32850/39406
# processing 32900/39406
# processing 32950/39406
# processing 33000/39406
# processing 33050/39406
# processing 33100/39406
# processing 33150/39406
# processing 33200/39406
# processing 33250/39406
# processing 33300/39406
# processing 33350/39406
# processing 33400/39406
# processing 33450/39406
# processing 33500/39406
# processing 33550/39406
# processing 33600/39406
# processing 33650/39406
# processing 33700/39406
# processing 33750/39406
# processing 33800/39406
# processing 33850/39406
# processing 33900/39406
# processing 33950/39406
# processing 34000/39406
# processing 34050/39406
# processing 34100/39406
# processing 34150/39406
# processing 34200/39406
# processing 34250/39406
# processing 34300/39406
# processing 34350/39406
# processing 34400/39406
# processing 34450/39406
# processing 34500/39406
# processing 34550/39406
# processing 34600/39406
# processing 34650/39406
# processing 34700/39406
# processing 34750/39406
# processing 34800/39406
# processing 34850/39406
# processing 34900/39406
# processing 34950/39406
# processing 35000/39406
# processing 35050/39406
# processing 35100/39406
# processing 35150/39406
# processing 35200/39406
# processing 35250/39406
# processing 35300/39406
# processing 35350/39406
# processing 35400/39406
# processing 35450/39406
# processing 35500/39406
# processing 35550/39406
# processing 35600/39406
# processing 35650/39406
# processing 35700/39406
# processing 35750/39406
# processing 35800/39406
# processing 35850/39406
# processing 35900/39406
# processing 35950/39406
# processing 36000/39406
# processing 36050/39406
# processing 36100/39406
# processing 36150/39406
# processing 36200/39406
# processing 36250/39406
# processing 36300/39406
# processing 36350/39406
# processing 36400/39406
# processing 36450/39406
# processing 36500/39406
# processing 36550/39406
# processing 36600/39406
# processing 36650/39406
# processing 36700/39406
# processing 36750/39406
# processing 36800/39406
# processing 36850/39406
# processing 36900/39406
# processing 36950/39406
# processing 37000/39406
# processing 37050/39406
# processing 37100/39406
# processing 37150/39406
# processing 37200/39406
# processing 37250/39406
# processing 37300/39406
# processing 37350/39406
# processing 37400/39406
# processing 37450/39406
# processing 37500/39406
# processing 37550/39406
# processing 37600/39406
# processing 37650/39406
# processing 37700/39406
# processing 37750/39406
# processing 37800/39406
# processing 37850/39406
# processing 37900/39406
# processing 37950/39406
# processing 38000/39406
# processing 38050/39406
# processing 38100/39406
# processing 38150/39406
# processing 38200/39406
# processing 38250/39406
# processing 38300/39406
# processing 38350/39406
# processing 38400/39406
# processing 38450/39406
# processing 38500/39406
# processing 38550/39406
# processing 38600/39406
# processing 38650/39406
# processing 38700/39406
# processing 38750/39406
# processing 38800/39406
# processing 38850/39406
# processing 38900/39406
# processing 38950/39406
# processing 39000/39406
# processing 39050/39406
# processing 39100/39406
# processing 39150/39406
# processing 39200/39406
# processing 39250/39406
# processing 39300/39406
# processing 39350/39406
# processing 39400/39406

# %%
file='17408x_19456y.png'

# %%
file.split('_')[1]
# Out:
# '19456y.png'
