# %%
import os, sys
notebook_dir = os.getcwd()
project_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
if project_dir not in sys.path:
    sys.path.append(project_dir)
modules_dir = os.path.abspath(os.path.join(notebook_dir, '..', 'modules'))
if modules_dir not in sys.path:
    sys.path.append(modules_dir)
import cv2
import numpy as np
from slide import Slide
from dsa import DSAFolder, DSAItem, DSA
import json

import glob

def check():
    print('checked')

def makeDir(mydir):
    if not os.path.exists(mydir):
        os.mkdir(mydir)

def generateAnno(contoursColors):

    annos = []
    elems = []

    for q in range(len(contoursColors)):
        cnts = contoursColors[q]['cnt']
        color = contoursColors[q]['color']

        for f in range(len(cnts)):
            cnt = cnts[f][0]
            hie = cnts[f][1]
            # print(hie)
            if hie[3]==-1:
                points = []
                for i in cnt:
                    for j in i:
                        x = int(j[0])
                        y = int(j[1])
                        points.append([x, y, 0])
    
                elem = {
                    "type": "polyline",
                    "lineColor": f"rgb({color})", 
                    "lineWidth": 3, 
                    "fillColor": f"rgba({color}, 0.5)",
                    "points": None,
                    "closed": True
                }

                elem["points"] = points

                if len(points)>1:
                    if (f+1)<len(cnts) and cnts[f+1][1][3]==-1: #No Children
                        pass
                    else: # Get Children
                        z = f+1
                        holes = []
                        while True:
                            hole = []
                            try:
                                cntChild = cnts[z][0]
                                hieChild = cnts[z][1]
                            except:
                                break
                            if hieChild[3]==-1:
                                break
                            for i in cntChild:
                                for j in i:
                                    x = int(j[0])
                                    y = int(j[1])
                                    hole.append([x, y, 0])
                            holes.append(hole)
                            z+=1
                        elem["holes"] = holes
                elems.append(elem)

    anno = {
        "name": 'newmodel_predicted', 
        "description": 'tbm_ai',  
        "elements": None                        
    }
    anno["elements"] = elems
    annos.append(anno)

    return annos



def getContours(mask):

    def smoothBinary(mask2d):
        kn = 2
        iterat = 2
        kernel = np.ones((kn, kn), np.uint8) 
        for _ in range(iterat):
            mask2d = cv2.erode(mask2d, kernel, iterations=1) 
            mask2d = cv2.dilate(mask2d, kernel, iterations=1) 
        return mask2d
    
    mask2 = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    
    maskSmooth = smoothBinary(mask2)

    thresholdArea = 0.0001

    contours, hierarchy = cv2.findContours(maskSmooth, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    print(f"found {len(contours)} contours")

    c_max = max(contours, key = cv2.contourArea)
    area_min = cv2.contourArea(c_max) * thresholdArea
    
    print(len(contours))
    
    cntheis = sorted(zip(contours, hierarchy[0]), key=lambda b: cv2.contourArea(b[0]) , reverse=True)
    
    mxmx = int(1.0 * len(contours))
    
    contours_filtered = []
    
    for qq in range(mxmx):
        # if qq%50==0:
            # print(f"processing {qq}/{mxmx}")
        contour = cntheis[qq][0]
        hie = cntheis[qq][1]
        contours_filtered.append((contour,hie))

    return contours_filtered

xx = 35873
yy = 58561

mask = np.zeros((yy, xx, 3), dtype='uint8')

# mydir = "/blue/pinaki.sarder/manojkumargalla/filtered_image_tiles/filtered_image/"
tiles_folder = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/"
# tiles_folder = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/new_model/predicted_tiles_set2_newmodel"
# tiles_folder = '/blue/pinaki.sarder/manojkumargalla/PostProcess/data/test_filtered_tiles/'
dsafid = {
        'S-2109-019197_PAS_2of2':'66d9d55d192b1e193a39db7a',
        'S-2109-019245_PAS_1of2':'66d9d562192b1e193a39db80',
        'S-2205-004663_PAS_1of2':'66d9d564192b1e193a39db86',
        'S-2205-014768_PAS_1of2':'66d9d56f192b1e193a39db8c',
        'S-2209-009410_PAS_1of2':'66d9d572192b1e193a39db92',
        'S-2109-019244_PAS_2of2':'66d9d560192b1e193a39db7d',
        'S-2205-004662_PAS_2of2':'66d9d563192b1e193a39db83',
        'S-2205-014767_PAS_2of2':'66d9d56a192b1e193a39db89',
        'S-2209-009409_PAS_2of2':'66d9d571192b1e193a39db8f',
        'S-2301-001175_PAS_1of2':'66d9d573192b1e193a39db95'
    }
filenames = glob.glob(f'{tiles_folder}/*/')
# print(filenames)
for filename in filenames:
    files = os.listdir(f'{filename}')
    fname = filename.split('/')[-2]
    print(f'processing file - {filename}')
    # print(files)
    xx = int(files[0].split('_')[0])
    yy = int(files[0].split('_')[1])
    # xx = int(files[0].split('_')[2])
    # yy = int(files[0].split('_')[3])
    mask = np.zeros((yy, xx, 3), dtype='uint8')
    for file in files:
        # lst = file.split('[')[-1].split(']')[0].replace("=", "").replace("x", "").replace("w", "").replace("y", "").replace("h", "").split(",")
        # print(lst)
        # print(file)
        x = int(file.split('_')[2].strip('x'))
        # x, y, w, h = [int(k) for k in lst]
        y = int(file.split('_')[3].split('.')[0].strip('y'))
        w, h = 512, 512
        # mask[y:y+h, x:x+w, :] = cv2.imread( f"{mydir}/{file}",3)
        img = cv2.imread( f"{filename}/{file}",3)
        h, w, _ = img.shape
        if y + h <= yy and x + w <= xx:
            mask[y:y+h, x:x+w, :] = img
        else:
            print(f"Skipping tile {file} due to out-of-bounds placement.")
            print(f'y + h is {y+h}, x + w is {x+w}')

    contours = getContours(mask)
    contoursColors = [{'cnt': contours, 'color': '255, 20, 20'}]
    # slides2 = [
    #     'S-2109-019197_PAS_2of2',
    #     'S-2109-019245_PAS_1of2',
    #     'S-2205-004663_PAS_1of2',
    #     'S-2205-014768_PAS_1of2',
    #     'S-2209-009410_PAS_1of2',
    #     'S-2109-019244_PAS_2of2',
    #     'S-2205-004662_PAS_2of2',
    #     'S-2205-014767_PAS_2of2',
    #     'S-2209-009409_PAS_2of2',
    #     'S-2301-001175_PAS_1of2'
    # ]
    # slides2 = list()
    # slides2.append(fname)
    # print(slides2)

    # annoooos = {}

    # for name in slides2:
    try:
        file_name = filename.split('/')[-2]
        annotations_filename = f'{file_name}_tbm_test.json'
        json_dir = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/TBM_Annotations_3/"
        makeDir(json_dir)
        # json_path = f'{json_dir}/{annotations_filename}'
        if os.path.exists(f'{json_dir}/{annotations_filename}'):
            print(f'{file_name} exists! Hence, continuing')
            continue

        # json_dir = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/new_model/TBM_Annotations_filtered"

        # json_dir = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/new_model/TBM_Annotations_oldmodel"
        


        # config = {
        #     'fid': dsafid[name],
        #     'username': 'manojkumargalla',
        #     'password': '3435isbcmon@G',
        #     'apiUrl': 'https://athena.rc.ufl.edu/api/v1',
        #     'layerName': 'tbm_geojson',
        #     'svsBase': "/blue/pinaki.sarder/nlucarelli/kpmp_new/"
        # }
        annos = generateAnno(contoursColors)
        with open(f'{json_dir}/{annotations_filename}', 'w') as outfile:
            json.dump(annos, outfile)

#             # annoooos[name] = annos

#             dsa = DSA(config)

#             fid = dsafid[name]

#             # annos = annoooos[name]
#             dsa.postAnno(fid, annos)
#             print('Annotations are posted on athena!')
    except Exception as e:
        print(e)
# Out:
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-1905-017738_PAS_1of2/
# found 418879 contours
# 418879
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-002084_PAS_1of3/
# found 133275 contours
# 133275
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-004277_PAS_2of2/
# found 84581 contours
# 84581
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-004324_PAS_2of2/
# found 76893 contours
# 76893
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-005094_PAS_1of2/
# found 197149 contours
# 197149
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-004230_PAS_2of2/
# found 221322 contours
# 221322
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-002045_PAS_1of2/
# found 65293 contours
# 65293
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2001-005357_PAS_1of2/
# found 101792 contours
# 101792
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-004811_PAS_1of2/
# found 69611 contours
# 69611
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-012854_PAS_2of2/
# found 282517 contours
# 282517
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-004953_PAS_1of2/
# found 32108 contours
# 32108
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-012855_PAS_1of2/
# found 230516 contours
# 230516
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-005000_PAS_1of2/
# found 71449 contours
# 71449
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-002044_PAS_2of2/
# found 89118 contours
# 89118
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-002095_PAS_2of3/
# found 128562 contours
# 128562
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-1909-007149_PAS_1of2/
# found 212565 contours
# 212565
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-004278_PAS_1of2/
# found 279101 contours
# 279101
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2010-004184_PAS_1of2/
# found 52107 contours
# 52107
# processing file - /blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/predicted_tiles_3/S-2006-005047_PAS_1of2/
# found 97503 contours
# 97503
