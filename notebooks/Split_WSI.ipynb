# %%
'''This cell uses python's multiprocessing library to parallelly process the splitting of images and uses cupy which is a Numpy-like library to enable GPU acceleration for image processing tasks'''
import cupy as cp
import multiprocessing as mp
from PIL import Image, ImageFilter
import tiffslide
import os
import glob
import numpy as np

def makeDir(mydir):
    if not os.path.exists(mydir):
        os.mkdir(mydir)

def process_file(file):
    filename = file.split('/')[-1].replace('.svs', '')
    try:
        slide = tiffslide.open_slide(file)
        nx, ny = slide.level_dimensions[0]
        ds = int(slide.level_downsamples[slide.level_count-1])
        print(f'Processing file name: {filename} nx: {nx}    ny: {ny}       downsample: {ds}')
        threshold = 200
        region = slide.read_region((0, 0), slide.level_count-1, slide.level_dimensions[slide.level_count-1])
        binary = region.convert('L').point(lambda p: 255 if p < threshold else 0)
        binary = binary.filter(ImageFilter.MedianFilter(size=29))
        binarynb = cp.array(binary)

        outdirSlide = f"{outdirbase}/{filename}"
        makeDir(outdirSlide)
        c=0
        for ix in range(nx // tileSize):
            if ix % 10 == 0:
                print(f"ix: {ix}/{nx // tileSize}, saved {c} images!")
                c=0
            for iy in range(ny // tileSize):
                xxx = int((ix * tileSize) / ds)
                yyy = int((iy * tileSize) / ds)
                slice_contains_255 = np.any(binarynb[yyy:yyy+tileSize//ds, xxx:xxx+tileSize//ds] == 255)
                # x = tileSize * ix
                # y = tileSize * iy
                # slice_region = binarynb[y:y + tileSize, y:y + tileSize]
                if slice_contains_255:
                # if cp.any(slice_region == 255):
                    # print(f'This has ones!!! {filename}')
                    # print(f'xxx for {filename} = {xxx} & yyy for {filename} = {yyy}')
                    # return
                    c+=1
                    x = tileSize * ix
                    y = tileSize * iy
                    tile = slide.read_region((x, y), 0, (tileSize, tileSize))
                    tile.save(f"{outdirSlide}/{str(nx)}_{str(ny)}_{str(x).zfill(5)}x_{str(y).zfill(5)}y.png")
    except Exception as e:
        print(f'Exception while processing file name: {filename} - {str(e)}')

tileSize = 512
outdirbase = f"/blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/tiles_3/"
makeDir(outdirbase)
datadir = "/blue/pinaki.sarder/manojkumargalla/PostProcess/data/model2/batch1/3/wsis_3/"
files = glob.glob(f"{datadir}/*.svs")

# Create a pool of workers and process files in parallel
with mp.Pool(processes=mp.cpu_count()) as pool:
    pool.map(process_file, files)
# Out:
# Processing file name: S-2006-004953_PAS_1of2 nx: 85698    ny: 34170       downsample: 32
# Processing file name: S-2006-005047_PAS_1of2 nx: 71747    ny: 37788       downsample: 32
# Processing file name: S-2010-004277_PAS_2of2 nx: 81712    ny: 32844       downsample: 32
# Processing file name: S-2006-002084_PAS_1of3 nx: 65768    ny: 38773       downsample: 32
# Processing file name: S-2006-005094_PAS_1of2 nx: 83705    ny: 54810       downsample: 32
# Processing file name: S-2006-002045_PAS_1of2 nx: 121572    ny: 43288       downsample: 32
# Processing file name: S-2010-004184_PAS_1of2 nx: 111607    ny: 44434       downsample: 32
# Processing file name: S-2001-005357_PAS_1of2 nx: 71747    ny: 52156       downsample: 32
# Processing file name: S-2006-005000_PAS_1of2 nx: 71747    ny: 49018       downsample: 32
# Processing file name: S-1905-017738_PAS_1of2 nx: 153460    ny: 57357       downsample: 64
# Processing file name: S-2006-002044_PAS_2of2 nx: 151467    ny: 65777       downsample: 64
# Processing file name: S-2010-012855_PAS_1of2 nx: 89684    ny: 70174       downsample: 32
# Processing file name: S-1909-007149_PAS_1of2 nx: 129544    ny: 61132       downsample: 32
# Processing file name: S-2010-012854_PAS_2of2 nx: 99649    ny: 85210       downsample: 32
# Processing file name: S-2006-002095_PAS_2of3 nx: 65768    ny: 37452       downsample: 32
# Processing file name: S-2010-004278_PAS_1of2 nx: 149474    ny: 49262       downsample: 64
# Processing file name: S-2010-004324_PAS_2of2 nx: 85698    ny: 26903       downsample: 32
# Processing file name: S-2006-004811_PAS_1of2 nx: 71747    ny: 64706       downsample: 32
# Processing file name: S-2010-004230_PAS_2of2 nx: 61782    ny: 43558       downsample: 16
# ix: 0/167, saved 0 images!
# ix: 0/291, saved 0 images!
# ix: 0/299, saved 0 images!
# ix: 0/128, saved 0 images!
# ix: 0/159, saved 0 images!
# ix: 0/128, saved 0 images!
# ix: 0/295, saved 0 images!
# ix: 0/167, saved 0 images!
# ix: 0/140, saved 0 images!
# ix: 0/217, saved 0 images!
# ix: 0/140, saved 0 images!
# ix: 0/140, saved 0 images!
# ix: 0/140, saved 0 images!
# ix: 0/163, saved 0 images!
# ix: 0/175, saved 0 images!
# ix: 0/237, saved 0 images!
# ix: 0/194, saved 0 images!
# ix: 0/253, saved 0 images!
# ix: 0/120, saved 0 images!
# ix: 10/167, saved 0 images!
# ix: 10/167, saved 0 images!
# ix: 10/140, saved 0 images!ix: 10/128, saved 0 images!
#
# ix: 10/128, saved 0 images!
# ix: 10/159, saved 0 images!
# ix: 10/291, saved 0 images!
# ix: 10/140, saved 0 images!ix: 10/140, saved 0 images!
#
# ix: 10/163, saved 0 images!
# ix: 10/217, saved 0 images!
# ix: 10/299, saved 0 images!ix: 10/120, saved 0 images!
#
# ix: 10/253, saved 0 images!
# ix: 10/295, saved 0 images!
# ix: 10/140, saved 0 images!ix: 10/175, saved 0 images!
#
# ix: 10/237, saved 3 images!
# ix: 20/128, saved 0 images!
# ix: 10/194, saved 0 images!
# ix: 20/140, saved 0 images!
# ix: 20/140, saved 3 images!
# ix: 20/299, saved 10 images!
# ix: 20/291, saved 19 images!
# ix: 20/159, saved 32 images!
# ix: 20/167, saved 46 images!
# ix: 20/217, saved 25 images!
# ix: 20/128, saved 43 images!
# ix: 20/140, saved 56 images!
# ix: 20/175, saved 50 images!
# ix: 30/128, saved 44 images!
# ix: 20/167, saved 77 images!
# ix: 20/194, saved 72 images!
# ix: 20/295, saved 60 images!
# ix: 20/237, saved 64 images!
# ix: 30/159, saved 57 images!
# ix: 30/167, saved 74 images!
# ix: 20/253, saved 100 images!
# ix: 20/140, saved 129 images!
# ix: 40/167, saved 47 images!
# ix: 50/167, saved 0 images!
# ix: 60/167, saved 0 images!
# ix: 70/167, saved 0 images!
# ix: 80/167, saved 0 images!
# ix: 90/167, saved 0 images!
# ix: 100/167, saved 0 images!
# ix: 110/167, saved 0 images!
# ix: 120/167, saved 0 images!
# ix: 130/167, saved 0 images!
# ix: 30/295, saved 61 images!
# ix: 30/167, saved 108 images!
# ix: 30/140, saved 159 images!
# ix: 30/237, saved 70 images!
# ix: 30/140, saved 170 images!
# ix: 40/159, saved 108 images!
# ix: 50/159, saved 2 images!
# ix: 30/217, saved 126 images!
# ix: 60/159, saved 0 images!
# ix: 70/159, saved 0 images!
# ix: 80/159, saved 0 images!
# ix: 90/159, saved 0 images!
# ix: 100/159, saved 0 images!
# ix: 110/159, saved 0 images!
# ix: 120/159, saved 0 images!
# ix: 20/120, saved 206 images!
# ix: 30/140, saved 176 images!
# ix: 40/217, saved 12 images!
# ix: 50/217, saved 0 images!
# ix: 60/217, saved 0 images!
# ix: 70/217, saved 0 images!
# ix: 80/217, saved 0 images!
# ix: 90/217, saved 0 images!
# ix: 40/167, saved 70 images!
# ix: 30/299, saved 208 images!
# ix: 140/167, saved 79 images!
# ix: 50/167, saved 23 images!
# ix: 60/167, saved 0 images!
# ix: 70/167, saved 0 images!
# ix: 80/167, saved 0 images!
# ix: 130/159, saved 54 images!
# ix: 90/167, saved 0 images!
# ix: 100/167, saved 0 images!
# ix: 110/167, saved 0 images!
# ix: 120/167, saved 0 images!
# ix: 30/128, saved 221 images!ix: 100/217, saved 23 images!
#
# ix: 40/295, saved 86 images!
# ix: 40/128, saved 35 images!
# ix: 40/128, saved 245 images!
# ix: 50/128, saved 0 images!
# ix: 60/128, saved 0 images!
# ix: 70/128, saved 0 images!
# ix: 80/128, saved 0 images!
# ix: 140/159, saved 68 images!
# ix: 30/175, saved 274 images!
# ix: 130/167, saved 65 images!
# ix: 150/167, saved 84 images!
# ix: 160/167, saved 0 images!
# ix: 90/128, saved 22 images!
# ix: 40/140, saved 109 images!
# ix: 20/163, saved 266 images!
# ix: 50/128, saved 55 images!
# ix: 60/128, saved 0 images!
# ix: 70/128, saved 0 images!
# ix: 30/291, saved 348 images!ix: 80/128, saved 0 images!
#
# ix: 90/128, saved 0 images!
# ix: 100/128, saved 0 images!
# ix: 40/140, saved 174 images!
# ix: 50/140, saved 0 images!
# ix: 60/140, saved 0 images!
# ix: 30/194, saved 288 images!
# ix: 70/140, saved 0 images!
# ix: 80/140, saved 0 images!
# ix: 110/217, saved 89 images!
# ix: 90/140, saved 0 images!
# ix: 100/140, saved 0 images!
# ix: 40/237, saved 134 images!
# ix: 30/120, saved 169 images!
# ix: 150/159, saved 71 images!
# ix: 50/140, saved 77 images!
# ix: 60/140, saved 0 images!
# ix: 70/140, saved 0 images!
# ix: 80/140, saved 0 images!
# ix: 90/140, saved 9 images!
# ix: 50/295, saved 93 images!
# ix: 140/167, saved 112 images!
# ix: 120/217, saved 46 images!
# ix: 130/217, saved 2 images!
# ix: 140/217, saved 0 images!
# ix: 150/217, saved 0 images!
# ix: 160/217, saved 0 images!
# ix: 170/217, saved 0 images!
# ix: 30/140, saved 300 images!
# ix: 40/140, saved 0 images!
# ix: 50/140, saved 0 images!
# ix: 60/140, saved 0 images!
# ix: 70/140, saved 0 images!
# ix: 180/217, saved 12 images!
# ix: 80/140, saved 0 images!
# ix: 90/140, saved 0 images!
# ix: 100/140, saved 0 images!
# ix: 50/237, saved 54 images!
# ix: 60/237, saved 0 images!
# ix: 70/237, saved 0 images!
# ix: 80/237, saved 0 images!
# ix: 90/237, saved 0 images!
# ix: 110/140, saved 19 images!
# ix: 40/120, saved 110 images!
# ix: 50/120, saved 0 images!
# ix: 60/120, saved 0 images!
# ix: 70/120, saved 0 images!
# ix: 80/120, saved 0 images!
# ix: 40/140, saved 290 images!
# ix: 50/140, saved 0 images!
# ix: 60/140, saved 0 images!
# ix: 70/140, saved 0 images!
# ix: 80/140, saved 0 images!
# ix: 90/140, saved 0 images!
# ix: 150/167, saved 79 images!
# ix: 30/253, saved 380 images!
# ix: 100/140, saved 5 images!
# ix: 40/175, saved 193 images!
# ix: 100/237, saved 41 images!
# ix: 60/295, saved 74 images!
# ix: 70/295, saved 0 images!
# ix: 80/295, saved 0 images!
# ix: 160/167, saved 25 images!
# ix: 90/295, saved 2 images!
# ix: 110/140, saved 163 images!
# ix: 40/299, saved 306 images!
# ix: 100/140, saved 135 images!
# ix: 40/194, saved 187 images!
# ix: 190/217, saved 71 images!
# ix: 100/128, saved 237 images!
# ix: 110/128, saved 229 images!
# ix: 110/237, saved 59 images!
# ix: 110/128, saved 48 images!
# ix: 120/128, saved 0 images!
# ix: 100/295, saved 62 images!
# ix: 200/217, saved 61 images!
# ix: 210/217, saved 9 images!
# ix: 90/120, saved 171 images!
# ix: 50/175, saved 155 images!
# ix: 110/140, saved 162 images!
# ix: 50/194, saved 145 images!
# ix: 110/295, saved 56 images!
# ix: 110/140, saved 162 images!
# ix: 30/163, saved 290 images!
# ix: 40/163, saved 0 images!
# ix: 50/163, saved 0 images!
# ix: 60/163, saved 0 images!
# ix: 70/163, saved 0 images!
# ix: 80/163, saved 0 images!
# ix: 90/163, saved 0 images!
# ix: 120/140, saved 166 images!
# ix: 100/163, saved 0 images!
# ix: 130/140, saved 0 images!
# ix: 110/163, saved 0 images!
# ix: 120/163, saved 0 images!
# ix: 130/163, saved 0 images!
# ix: 120/237, saved 89 images!
# ix: 120/128, saved 165 images!
# ix: 60/175, saved 131 images!
# ix: 120/140, saved 93 images!
# ix: 120/295, saved 72 images!
# ix: 130/140, saved 22 images!
# ix: 60/194, saved 132 images!
# ix: 40/291, saved 479 images!
# ix: 100/120, saved 187 images!
# ix: 50/299, saved 313 images!
# ix: 40/253, saved 348 images!ix: 120/140, saved 384 images!
#
# ix: 130/140, saved 0 images!
# ix: 70/175, saved 81 images!
# ix: 80/175, saved 2 images!
# ix: 90/175, saved 0 images!
# ix: 100/175, saved 0 images!
# ix: 110/175, saved 0 images!
# ix: 130/295, saved 70 images!
# ix: 70/194, saved 99 images!
# ix: 50/253, saved 55 images!
# ix: 60/253, saved 0 images!
# ix: 70/253, saved 0 images!
# ix: 80/253, saved 0 images!
# ix: 80/194, saved 17 images!
# ix: 90/253, saved 0 images!
# ix: 90/194, saved 0 images!
# ix: 100/253, saved 0 images!
# ix: 100/194, saved 0 images!
# ix: 110/194, saved 0 images!
# ix: 110/253, saved 0 images!
# ix: 130/237, saved 134 images!
# ix: 120/253, saved 9 images!
# ix: 140/237, saved 4 images!
# ix: 150/237, saved 0 images!
# ix: 160/237, saved 0 images!
# ix: 170/237, saved 0 images!
# ix: 110/120, saved 111 images!
# ix: 120/194, saved 22 images!
# ix: 120/140, saved 258 images!
# ix: 130/140, saved 0 images!
# ix: 180/237, saved 19 images!
# ix: 50/291, saved 157 images!
# ix: 60/291, saved 0 images!
# ix: 70/291, saved 0 images!
# ix: 80/291, saved 0 images!
# ix: 90/291, saved 0 images!
# ix: 100/291, saved 0 images!
# ix: 110/291, saved 0 images!
# ix: 120/291, saved 0 images!
# ix: 130/291, saved 0 images!
# ix: 140/291, saved 0 images!
# ix: 150/291, saved 0 images!
# ix: 130/253, saved 59 images!
# ix: 160/291, saved 25 images!
# ix: 140/295, saved 96 images!
# ix: 150/295, saved 0 images!
# ix: 160/295, saved 0 images!
# ix: 170/295, saved 0 images!
# ix: 180/295, saved 0 images!
# ix: 190/295, saved 0 images!
# ix: 200/295, saved 0 images!
# ix: 140/253, saved 52 images!
# ix: 210/295, saved 0 images!
# ix: 170/291, saved 51 images!
# ix: 190/237, saved 63 images!
# ix: 220/295, saved 21 images!
# ix: 60/299, saved 240 images!
# ix: 180/291, saved 51 images!
# ix: 190/291, saved 0 images!
# ix: 200/291, saved 0 images!
# ix: 210/291, saved 0 images!
# ix: 220/291, saved 0 images!
# ix: 230/291, saved 0 images!
# ix: 240/291, saved 0 images!
# ix: 250/291, saved 0 images!
# ix: 260/291, saved 7 images!
# ix: 70/299, saved 26 images!
# ix: 80/299, saved 0 images!
# ix: 90/299, saved 0 images!
# ix: 100/299, saved 12 images!
# ix: 120/175, saved 258 images!
# ix: 150/253, saved 112 images!
# ix: 140/163, saved 326 images!
# ix: 160/253, saved 10 images!
# ix: 170/253, saved 0 images!
# ix: 270/291, saved 40 images!
# ix: 180/253, saved 0 images!
# ix: 190/253, saved 0 images!
# ix: 200/253, saved 0 images!
# ix: 230/295, saved 61 images!
# ix: 200/237, saved 71 images!
# ix: 210/253, saved 22 images!
# ix: 110/299, saved 80 images!
# ix: 280/291, saved 60 images!
# ix: 290/291, saved 14 images!
# ix: 220/253, saved 58 images!
# ix: 240/295, saved 58 images!
# ix: 130/194, saved 326 images!
# ix: 120/299, saved 78 images!
# ix: 230/253, saved 70 images!
# ix: 130/299, saved 75 images!
# ix: 130/175, saved 234 images!
# ix: 250/295, saved 76 images!
# ix: 210/237, saved 148 images!
# ix: 240/253, saved 92 images!
# ix: 250/253, saved 0 images!
# ix: 140/299, saved 72 images!
# ix: 220/237, saved 25 images!
# ix: 230/237, saved 0 images!
# ix: 140/194, saved 194 images!
# ix: 150/163, saved 215 images!
# ix: 160/163, saved 0 images!
# ix: 260/295, saved 74 images!
# ix: 150/299, saved 71 images!
# ix: 140/175, saved 162 images!
# ix: 160/299, saved 70 images!
# ix: 150/194, saved 146 images!
# ix: 270/295, saved 82 images!
# ix: 170/299, saved 67 images!
# ix: 280/295, saved 14 images!
# ix: 290/295, saved 0 images!
# ix: 180/299, saved 17 images!
# ix: 190/299, saved 0 images!
# ix: 200/299, saved 0 images!
# ix: 210/299, saved 0 images!
# ix: 150/175, saved 134 images!
# ix: 220/299, saved 29 images!
# ix: 160/175, saved 47 images!
# ix: 170/175, saved 0 images!
# ix: 160/194, saved 127 images!
# ix: 230/299, saved 82 images!
# ix: 170/194, saved 72 images!
# ix: 180/194, saved 0 images!
# ix: 190/194, saved 0 images!
# ix: 240/299, saved 78 images!
# ix: 250/299, saved 75 images!
# ix: 260/299, saved 74 images!
# ix: 270/299, saved 70 images!
# ix: 280/299, saved 73 images!
# ix: 290/299, saved 53 images!
